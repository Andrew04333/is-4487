# %% [markdown]
# IS 4487 Lab 1 - Python Intro
#
# **Outline**
#
# - Create and format cells in a notebook
# - Create basic variables in Python
# - Experiment with how to use AI to assist with a task.

# %% [markdown]
# ### Task 1 - Add 15 and 22

# %%
print(15 + 22)
# Out:
# 37

# %% [markdown]
# ### Task 2 - About Me
#
# **Major:** Finance
#
# **Favorite food:** Pizza

# %% [markdown]
# ### Task 3 - Create and print variable x

# %%
x = "Hello World"
print(x)
# Out:
# Hello World

# %% [markdown]
# ### Task 4 - Word art with the `art` library

# %%
# !pip install art
from art import text2art
print(text2art("Andrew Johnson"))
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/610.4 kB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 610.4/610.4 kB 15.2 MB/s eta 0:00:00
# ...
#     _                _                             _         _
#    / \    _ __    __| | _ __   ___ __      __     | |  ___  | |__   _ __   ___   ___   _ __
#   / _ \  | '_ \  / _` || '__| / _ \\ \ /\ / /  _  | | / _ \ | '_ \ | '_ \ / __| / _ \ | '_ \
#  / ___ \ | | | || (_| || |   |  __/ \ V  V /  | |_| || (_) || | | || | | |\__ \| (_) || | | |
# /_/   \_\|_| |_| \__,_||_|    \___|  \_/\_/    \___/  \___/ |_| |_||_| |_||___/ \___/ |_| |_|

# %% [markdown]
# ### Task 5: Reflection
#
# **1. Describe your feelings as you wrote Python code? Does this feel intimidating or fun?**
#
# Writing Python for this lab felt familiar rather than intimidating — I already work with `.py` files in fintech, so the syntax and workflow weren't new to me. If anything, it was a nice change of pace to work with something this simple after dealing with production code.
#
# **2. What would be a good strategy in working with AI to ensure that you are driving the process and learning, as opposed to giving control to Gemini?**
#
# A good strategy is setting clear boundaries for what you're asking AI to do — being specific in your prompts about the exact task, rather than vague requests that leave too much up to the model. Combined with reviewing every line it produces before running it, this keeps you directing the process instead of just accepting whatever comes back.
